# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
sns.set_style("whitegrid")
import altair as alt
#alt.renderers.enable("notebook")

# Code for hiding seaborn warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df_path = 'racmyp_articles_all.csv'
df = pd.read_csv(df_path, sep=',')

# %%
df.head()
# Out:
#                                           categories title_categories  \
# 0         ['Ciclos Monográficos. Generación del 98']               []
# 1                                 ['Vida Académica']               []
# 2  ['Intervenciones Académicas. Secciones. Cienci...               []
# 3  ['Intervenciones Académicas. Secciones. Cienci...               []
# 4  ['Intervenciones Académicas. Secciones. Cienci...               []
#
#   summarize_categories                                            title  \
# 0                   []                       Lo vivo y lo muerto del 98
# 1                   []                                         TRIBUNAS
# 2                   []  Innovar para internacionalizar e industrializar
# 3                   []                Sobre el modo histórico de pensar
# 4                   []                               El poder moderador
#
#                          author  facicle  year  start_page  end_page  \
# 0  Gonzalo Fernández De La Mora        1  1998         515       523
# 1                        RACMYP        1  1996         713       713
# 2        Juan Miguel Villar Mir        1  2015         291       311
# 3          Dalmacio Negro Pavón        1  2015         337       362
# 4        Sabino Fernández Campo        1  2007         363       374
#
#                                   pdf_link
# 0  abrir_pdf.php?id=ANU-M-1998-10051500523
# 1  abrir_pdf.php?id=ANU-M-1996-10071300713
# 2  abrir_pdf.php?id=ANU-M-2015-10029100311
# 3  abrir_pdf.php?id=ANU-M-2015-10033700362
# 4  abrir_pdf.php?id=ANU-M-2007-10036300374

# %%
df["id"].count()
# Out:
# 1693

# %%
len(pd.unique(df['category']))
# Out:
# 77

# %%
df.loc[:,"category"]
# Out:
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
#                               ...
# 1688                         ['Reflexiones', 'concordia']
# 1689          ['Puebla', 'Belmonte', 'Historia', 'campo']
# 1690    ['Fecho Imperio', 'Reflexiones', 'centenario',...
# 1691         ['Seminarios', 'mesas', '1.2 Publicaciones']
# 1692    ['2.1 Académicos', 'Representación', 'Honores'...
# Name: title_categories, Length: 1693, dtype: object

# %%
bars = alt.Chart(df).mark_bar(size=50).encode(
    x=alt.X("category"),
    y=alt.Y("count():Q", axis=alt.Axis(title='Number of articles')),
    tooltip=[alt.Tooltip('count()', title='Number of articles'), 'category'],
    color='category'

)

text = bars.mark_text(
    align='center',
    baseline='bottom',
).encode(
    text='count()'
)

(bars + text).interactive().properties(
    height=300, 
    width=700,
    title = "Number of articles in each category",
)
# Out:
# alt.LayerChart(...)

# %%
new = df["category"].str.split(".", n = 1, expand = True)

# %%
df["category"] = new[0]

# %%
len(pd.unique(df['category']))
# Out:
# 27

# %%
bars = alt.Chart(df).mark_bar(size=50).encode(
    x=alt.X("category"),
    y=alt.Y("count():Q", axis=alt.Axis(title='Number of articles')),
    tooltip=[alt.Tooltip('count()', title='Number of articles'), 'category'],
    color='category'

)

text = bars.mark_text(
    align='center',
    baseline='bottom',
).encode(
    text='count()'
)

(bars + text).interactive().properties(
    height=300, 
    width=700,
    title = "Number of articles in each category",
)
# Out:
# alt.LayerChart(...)

# %%
df.loc[:,"category"].unique()
# Out:
# array(['Filosofía y Política', 'Sociología y Economía',
#        'Figuras Intelectuales', 'Vida Académica', 'Necrológicas',
#        'Ciencias Jurídicas', 'Figuras Académicas', 'Editorial',
#        'Filosofía', 'Política', 'Filosofía Social', 'Política y Derecho',
#        'Teología y Filosofía', 'Política y Sociología', 'Economía',
#        'Derecho', 'Sociología Económica', 'Ciencias Sociales', 'Ciclos',
#        'Otras Actividades Académicas', 'Intervenciones Académicas',
#        'Ciclo sobre ética', 'Ciclos Monográficos', 'Presentación',
#        'Noticiario Académico', 'Veinticinco años de la Constitución',
#        'Actas de la ponencia Constitucional'], dtype=object)

# %%
df['id'] = 1
df2 = pd.DataFrame(df.groupby('category').count()['id']).reset_index()

bars = alt.Chart(df2).mark_bar(size=50).encode(
    x=alt.X('category'),
    y=alt.Y('PercentOfTotal:Q', axis=alt.Axis(format='.0%', title='% of Articles')),
    color='category'
).transform_window(
    TotalArticles='sum(id)',
    frame=[None, None]
).transform_calculate(
    PercentOfTotal="datum.id / datum.TotalArticles"
)

text = bars.mark_text(
    align='center',
    baseline='bottom',
    #dx=5  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text=alt.Text('PercentOfTotal:Q', format='.1%')
)

(bars + text).interactive().properties(
    height=300, 
    width=700,
    title = "% of articles in each category",
)
# Out:
# alt.LayerChart(...)
